# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Mumbai House Prices.csv")

# %%
df['Total_Price'] = pd.cut(df["price"] , bins = [0, 1.5, 3.0, 4.5, 6.0, np.inf] , labels = [1 , 2 , 3 , 4 , 5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits = 1 , test_size = 0.2 , random_state = 42)

for train_index, test_index in split.split(df, df["Total_Price"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
#Removing the total price column
for col in (strat_train_set , strat_test_set):
    col.drop("Total_Price" , axis = 1 , inplace = True)

# %%
df = strat_train_set .copy()

# %%
df
# Out:
#        bhk       type                          locality  area  price  \
# 73794    1  Apartment            Runwal Codename BeWise   422  73.00
# 48108    2  Apartment  Shailesh Riddhi Siddhi Residency  1125  95.00
# 23011    3  Apartment             Shagun Silver Heights  1450   1.00
# 8119     1  Apartment              Laxmi Kailash Garden   755  51.00
# 34876    2  Apartment                        Alag Olive   728   1.44
# ...    ...        ...                               ...   ...    ...
# 40904    3  Apartment                 SD Siennaa Wing B  1572   2.37
# 72458    2  Apartment                 Rustomjee Urbania   848   1.58
# 62179    2  Apartment                 Indiabulls Greens  1300  95.00
# 11411    4  Apartment                        Bombay ICC  2550  10.75
# 41915    1  Apartment        A And O A And O Excellente   313  72.50
#
#       price_unit          region              status     age
# 73794          L      Thane West  Under Construction     New
# 48108          L            Ulwe       Ready to move  Resale
# 23011         Cr            Ulwe       Ready to move  Resale
# 8119           L     Kalyan West       Ready to move  Resale
# 34876         Cr  Ghatkopar East  Under Construction     New
# ...          ...             ...                 ...     ...
# 40904         Cr  Kandivali East  Under Construction     New
# 72458         Cr      Thane West       Ready to move     New
# 62179          L          Panvel  Under Construction     New
# 11411         Cr          Wadala       Ready to move  Resale
# 41915          L     Mulund West  Under Construction     New
#
# [60830 rows x 9 columns]

# %%
housing = strat_train_set.drop("area" , axis = 1)
housing_label = strat_train_set['area'].copy()

# %%
housing
# Out:
#        bhk       type                          locality  price price_unit  \
# 73794    1  Apartment            Runwal Codename BeWise  73.00          L
# 48108    2  Apartment  Shailesh Riddhi Siddhi Residency  95.00          L
# 23011    3  Apartment             Shagun Silver Heights   1.00         Cr
# 8119     1  Apartment              Laxmi Kailash Garden  51.00          L
# 34876    2  Apartment                        Alag Olive   1.44         Cr
# ...    ...        ...                               ...    ...        ...
# 40904    3  Apartment                 SD Siennaa Wing B   2.37         Cr
# 72458    2  Apartment                 Rustomjee Urbania   1.58         Cr
# 62179    2  Apartment                 Indiabulls Greens  95.00          L
# 11411    4  Apartment                        Bombay ICC  10.75         Cr
# 41915    1  Apartment        A And O A And O Excellente  72.50          L
#
#                region              status     age
# 73794      Thane West  Under Construction     New
# 48108            Ulwe       Ready to move  Resale
# 23011            Ulwe       Ready to move  Resale
# 8119      Kalyan West       Ready to move  Resale
# 34876  Ghatkopar East  Under Construction     New
# ...               ...                 ...     ...
# 40904  Kandivali East  Under Construction     New
# 72458      Thane West       Ready to move     New
# 62179          Panvel  Under Construction     New
# 11411          Wadala       Ready to move  Resale
# 41915     Mulund West  Under Construction     New
#
# [60830 rows x 8 columns]

# %%
housing_label
# Out:
# 73794     422
# 48108    1125
# 23011    1450
# 8119      755
# 34876     728
#          ...
# 40904    1572
# 72458     848
# 62179    1300
# 11411    2550
# 41915     313
# Name: area, Length: 60830, dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")

housing_num = housing.select_dtypes(include=[np.number])
imputer.fit(housing_num)
# Out:
# SimpleImputer(strategy='median')

# %%
X = imputer.transform(housing_num)

# %%
X
# Out:
# array([[ 1.  , 73.  ],
#        [ 2.  , 95.  ],
#        [ 3.  ,  1.  ],
#        ...,
#        [ 2.  , 95.  ],
#        [ 4.  , 10.75],
#        [ 1.  , 72.5 ]], shape=(60830, 2))
